# %%
import matplotlib.pyplot as plt

# %%
savings = [100,200,230,400,300,1000,600]
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul"]

# %%
plt.plot(months,savings)
plt.xlabel("Months")
plt.ylabel("Savings ($)")
plt.title("Savings By Month")
plt.show()
